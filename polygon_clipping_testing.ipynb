# %%
# SETUP
# =====
from classes import *
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt


# TEST DATA
# =========
# a small group of points, spatially ordered
sample1 = [[0,10], [5,0], [10,10], [15,0], [20,10], [25, 0],
             [30, 20], [35, 15], [45, 0], [50, 50], [45, 40], 
             [40, 50], [30, 45], [25, 40], [20, 30], [15, 50],
             [10,35], [5, 50],[5,50], [0, 10]]

sample2 = [[0,1],  [2,1], [26, 0],
             [26, 35], [40, 55],
             [18,34], [0, 1]]
             

print(sample1)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# [[0, 10], [5, 0], [10, 10], [15, 0], [20, 10], [25, 0], [30, 20], [35, 15], [45, 0], [50, 50], [45, 40], [40, 50], [30, 45], [25, 40], [20, 30], [15, 50], [10, 35], [5, 50], [5, 50], [0, 10]]

# %%
# DEMO WITH SMALL DATASET
# ====
# create polygon from sample1 - Polygon expects a list of points, each with x,y coords
samplePolygon1 = Polygon(sample1, xcol=0, ycol=1)
print(samplePolygon1)

# we can test if it is a closed polygon (first and last points have the same coordinates)
print(f"Polygon is closed: {samplePolygon1.isClosed()}")

xs1 = [i.x for i in samplePolygon1]
ys1 = [i.y for i in samplePolygon1]

samplePolygon2 = Polygon(sample2, xcol=0, ycol=1)
print(samplePolygon2)

# we can test if it is a closed polygon (first and last points have the same coordinates)
print(f"Polygon is closed: {samplePolygon2.isClosed()}")

xs2 = [i.x for i in samplePolygon2]
ys2 = [i.y for i in samplePolygon2]


plt.plot(xs1, ys1, linestyle='dashed')
plt.plot(xs2, ys2, linestyle='dashed')
# Out:
# Polygon PointGroup containing 20 points
# Polygon is closed: True
# Polygon PointGroup containing 7 points
# Polygon is closed: True

# %%
p3 = samplePolygon1.clip(samplePolygon2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 p3 = samplePolygon1.clip(samplePolygon2)
#
# File ~/Projekte/Uzh/GEO877_Spatial_Algorithms/SpatialAlgorithms/classes.py:260, in Polygon.clip(self, subject_polygon)
#     257 output = []
#     259 # Clip each polygon in the input list against the current clip edge
# --> 260 clipped = self.clip_polygon_against_edge(input_polygon, clip_edge)
#     261 output.extend(clipped)
#     263 if not output:
#
# File ~/Projekte/Uzh/GEO877_Spatial_Algorithms/SpatialAlgorithms/classes.py:275, in Polygon.clip_polygon_against_edge(self, polygon, clip_edge)
#     273 for i, v1 in enumerate(input_vertices):
#     274     v2 = input_vertices[(i + 1) % len(input_vertices)]
# --> 275     if self.inside(v2, clip_edge):
#     276         if not self.inside(v1, clip_edge):
# ...
